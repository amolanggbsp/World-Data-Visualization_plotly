# %%
import pandas as pd
GDP_comp = pd.read_csv('GDP_composition.csv')
GDP_comp
GDP_comp1 = GDP_comp.T
GDP_comp1
print("_________________________________________________________________________________________________________________________")
print("Get GDP composition")
print("Category: 1.household consumption, 2.gov comsumption 3.inv in fc 4. inv in inventories 5. expoert of S&G  6.imports of S&G")
a = input("type the country name: ")
for i in range(0,30):
    if GDP_comp1.iloc[ : , i][0] == a:
        print()
        print (GDP_comp1.iloc[ : , i])
# Out:
# _________________________________________________________________________________________________________________________
# Get GDP composition
# Category: 1.household consumption, 2.gov comsumption 3.inv in fc 4. inv in inventories 5. expoert of S&G  6.imports of S&G
# type the country name: japan
#
# country name                   japan
# household consumption           55.9
# government consumption          19.5
# investment in fixed capital     23.5
# investment in inventories        0.2
# exports of S&G                  17.8
# imports of S&G                 -16.8
# Name: 0, dtype: object

# %%
gdp_comp = pd.read_csv("GDP_composition.csv") 
print("______________GDP Composition by country____________")
gdp_comp
# Out:
# ______________GDP Composition by country____________
#       country name  household consumption  government consumption  \
# 0            japan                   55.9                    19.5
# 1            india                   58.7                    11.6
# 2            china                   39.1                    14.6
# 3         thailand                   50.1                    17.0
# 4          vietnam                   68.5                     6.6
# 5         cambodia                   76.4                     5.4
# 6        singapore                   34.7                    11.4
# 7        indonesia                   57.5                     8.9
# 8           canada                   58.1                    20.9
# 9    united_states                   69.1                    17.2
# 10  united_kingdom                   65.3                    19.0
# 11         germany                   53.7                    19.9
# 12          france                   54.8                    23.5
# 13           italy                   60.2                    18.7
# 14           spain                   57.3                    18.5
# 15     philippines                   72.7                    10.9
# 16     south_korea                   47.8                    15.2
# 17          mexico                   68.0                    12.5
# 18         austria                   52.1                    19.8
# 19          poland                   58.8                    18.1
# 20        portugal                   65.7                    17.6
# 21           egypt                   79.2                    12.2
# 22         denmark                   48.0                    25.2
# 23       australia                   57.1                    19.0
# 24        cambodia                   76.4                     5.4
# 25         belgium                   50.8                    23.3
# 26           sudan                   77.3                     6.1
# 27          russia                   52.4                    17.8
# 28          norway                   44.7                    24.6
# 29    saudi_arabia                   41.3                    24.6
#
#     investment in fixed capital  investment in inventories  exports of S&G  \
# 0                          23.5                        0.2            17.8
# 1                          27.5                        4.0            18.4
# 2                          43.3                        1.1            19.6
# 3                          24.2                       -7.0            70.4
# 4                          24.8                        2.9            98.6
# 5                          22.0                        0.9            62.8
# 6                          23.5                        1.9           179.2
# 7                          32.1                        0.7            19.2
# 8                          22.8                        0.3            31.4
# 9                          16.3                        0.3            12.2
# 10                         16.6                        0.7            30.1
# 11                         20.1                       -1.0            47.3
# 12                         22.0                        1.3            30.3
# 13                         17.2                        0.1            31.8
# 14                         19.8                        0.4            34.2
# 15                         25.2                       -0.2            32.1
# 16                         29.4                        0.3            43.9
# 17                         22.1                       -1.3            37.4
# 18                         23.1                        1.1            54.2
# 19                         17.8                        0.8            56.2
# 20                         15.4                       -0.2            42.9
# 21                         17.3                        1.3            13.5
# 22                         20.0                       -0.2            54.5
# 23                         24.2                        0.0            20.5
# 24                         22.0                        0.9            62.8
# 25                         23.0                        0.5            87.7
# 26                         18.5                        0.9             8.9
# 27                         21.1                        2.5            25.6
# 28                         23.8                        4.0            36.4
# 29                         24.4                        4.4            35.6
#
#     imports of S&G
# 0            -16.8
# 1            -20.2
# 2            -17.7
# 3            -54.7
# 4           -101.4
# 5            -67.4
# 6           -150.6
# 7            -18.4
# 8            -33.6
# 9            -15.1
# 10           -31.7
# 11           -40.0
# 12           -32.0
# 13           -28.0
# 14           -30.2
# 15           -40.7
# 16           -36.7
# 17           -38.7
# 18           -50.3
# 19           -51.8
# 20           -41.4
# 21           -23.5
# 22           -47.5
# 23           -20.8
# 24           -67.4
# 25           -85.3
# 26           -11.7
# 27           -19.4
# 28           -33.5
# 29           -30.3

# %%
GDP_comp1
# Out:
#                                 0      1      2         3        4         5   \
# country name                 japan  india  china  thailand  vietnam  cambodia
# household consumption         55.9   58.7   39.1      50.1     68.5      76.4
# government consumption        19.5   11.6   14.6        17      6.6       5.4
# investment in fixed capital   23.5   27.5   43.3      24.2     24.8        22
# investment in inventories      0.2      4    1.1        -7      2.9       0.9
# exports of S&G                17.8   18.4   19.6      70.4     98.6      62.8
# imports of S&G               -16.8  -20.2  -17.7     -54.7   -101.4     -67.4
#
#                                     6          7       8              9   \
# country name                 singapore  indonesia  canada  united_states
# household consumption             34.7       57.5    58.1           69.1
# government consumption            11.4        8.9    20.9           17.2
# investment in fixed capital       23.5       32.1    22.8           16.3
# investment in inventories          1.9        0.7     0.3            0.3
# exports of S&G                   179.2       19.2    31.4           12.2
# imports of S&G                  -150.6      -18.4   -33.6          -15.1
#
#                                  ...             20     21       22  \
# country name                     ...       portugal  egypt  denmark
# household consumption            ...           65.7   79.2       48
# government consumption           ...           17.6   12.2     25.2
# investment in fixed capital      ...           15.4   17.3       20
# investment in inventories        ...           -0.2    1.3     -0.2
# exports of S&G                   ...           42.9   13.5     54.5
# imports of S&G                   ...          -41.4  -23.5    -47.5
#
#                                     23        24       25     26      27  \
# country name                 australia  cambodia  belgium  sudan  russia
# household consumption             57.1      76.4     50.8   77.3    52.4
# government consumption              19       5.4     23.3    6.1    17.8
# investment in fixed capital       24.2        22       23   18.5    21.1
# investment in inventories            0       0.9      0.5    0.9     2.5
# exports of S&G                    20.5      62.8     87.7    8.9    25.6
# imports of S&G                   -20.8     -67.4    -85.3  -11.7   -19.4
#
#                                  28            29
# country name                 norway  saudi_arabia
# household consumption          44.7          41.3
# government consumption         24.6          24.6
# investment in fixed capital    23.8          24.4
# investment in inventories         4           4.4
# exports of S&G                 36.4          35.6
# imports of S&G                -33.5         -30.3
#
# [7 rows x 30 columns]

# %%
GDP_comp2= GDP_comp1.iloc[ 1: , ]
japan = GDP_comp2.iloc[ : , 0]
japan
# Out:
# household consumption          55.9
# government consumption         19.5
# investment in fixed capital    23.5
# investment in inventories       0.2
# exports of S&G                 17.8
# imports of S&G                -16.8
# Name: 0, dtype: object

# %%
import plotly.plotly as py
import plotly.graph_objs as go

fig = {
  "data": [
    {
      "values":  japan,
      "labels": [
        "household consumption",
        "gov consumption",
        "investment in fixed capital",
        "investment in inventories",
        "exports of S&G",
        "imports of S&G",
      ],
      "domain": {"column": 0},
      "name": "GDP",
      "hoverinfo":"label+percent+name",
      "hole": .4,
      "type": "pie"
    }],
  "layout": {
        "title":"GDP Composition"+" Japan",
        "grid": {"rows": 1, "columns": 1},
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "GDP",
                "x": 0.50,
                "y": 0.5
            }]
    }
}
py.iplot(fig, filename='donut')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~BOSUNG/12.embed" height="525px" width="100%"></iframe>

# %%
import pandas as pd
GDP_comp = pd.read_csv('GDP_composition.csv')
GDP_comp
GDP_comp1 = GDP_comp.T
GDP_comp2= GDP_comp1.iloc[ 1: , ]

print("_________________________________________________________________________________________________________________________")
print("Get GDP composition")
print("Category: 1.household consumption, 2.gov comsumption 3.inv in fc 4. inv in inventories 5. expoert of S&G  6.imports of S&G")

a = input("type the country name: ")
for i in range(0,30):
    if GDP_comp1.iloc[ : , i][0] == a:
        print()
        print (GDP_comp1.iloc[ : , i])
fig = {
  "data": [
    {
      "values": GDP_comp2.iloc[ : , i],
      "labels": [
        "household consumption",
        "gov consumption",
        "investment in fixed capital",
        "investment in inventories",
        "exports of S&G",
        "imports of S&G",
      ],
        'marker': {'colors': ['rgb(244, 66, 241)',
                                  'rgb(244, 65, 143)',
                                  'rgb(226, 0, 98)',
                                  'rgb(145, 21, 97)',
                                  'rgb(186, 24, 75)',
                              'rgb(186, 24, 183)']},
      "domain": {"column": 0},
      "name": "GDP",
      "hoverinfo":"label+percent+name",
      "hole": .4,
      "type": "pie"
    }],
  "layout": {
        "title":"GDP Composition"+ " "+ str(a),
        "grid": {"rows": 1, "columns": 1},
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "GDP",
                "x": 0.50,
                "y": 0.5
            }]
    }
}
py.iplot(fig, filename='donut')
# Out:
# _________________________________________________________________________________________________________________________
# Get GDP composition
# Category: 1.household consumption, 2.gov comsumption 3.inv in fc 4. inv in inventories 5. expoert of S&G  6.imports of S&G
# type the country name: mexico
#
# country name                   mexico
# household consumption              68
# government consumption           12.5
# investment in fixed capital      22.1
# investment in inventories        -1.3
# exports of S&G                   37.4
# imports of S&G                  -38.7
# Name: 17, dtype: object
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~BOSUNG/12.embed" height="525px" width="100%"></iframe>

# %%
import pandas as pd
import plotly.plotly as py

GDP_comp = pd.read_csv('GDP_composition.csv')
GDP_comp
GDP_comp1 = GDP_comp.T
GDP_comp2= GDP_comp1.iloc[ 1: , ]

print("_________________________________________________________________________________________________________________________")
print("Get GDP composition")
print("Category: 1.household consumption, 2.gov comsumption 3.inv in fc 4. inv in inventories 5. expoert of S&G  6.imports of S&G")

while True:
    a = input("type the country name: ")
    for i in range(0,30):
        if GDP_comp1.iloc[ : , i][0] == a:
            print()
            print (GDP_comp1.iloc[ : , i])
    fig = {
      "data": [
        {
          "values": GDP_comp2.iloc[ : , i],
          "labels": [
            "household consumption",
            "gov consumption",
            "investment in fixed capital",
            "investment in inventories",
            "exports of S&G",
            "imports of S&G",
          ],
            'marker': {'colors': ['rgb(244, 66, 241)',
                                      'rgb(244, 65, 143)',
                                      'rgb(226, 0, 98)',
                                      'rgb(145, 21, 97)',
                                      'rgb(186, 24, 75)',
                                  'rgb(186, 24, 183)']},
          "domain": {"column": 0},
          "name": "GDP",
          "hoverinfo":"label+percent+name",
          "hole": .4,
          "type": "pie"
        }],
      "layout": {
            "title":"GDP Composition"+ " "+ str(a),
            "grid": {"rows": 1, "columns": 1},
            "annotations": [
                {
                    "font": {
                        "size": 20
                    },
                    "showarrow": False,
                    "text": "GDP",
                    "x": 0.50,
                    "y": 0.5
                }]
        }
    }
    py.iplot(fig, filename='donut')
        if a == 0 :
            break
